# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from src.data import  load_raw_data
rides = load_raw_data(year=2022)
rides
# Out:
# Downloading file 2023
# 2023 file is not available
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from src.data import  load_raw_data
# ----> 2 rides = load_raw_data(year=2023)
#       3 rides
#
# File D:\ML System 02\bike_sharing_ML_System\src\data.py:176, in load_raw_data(year)
#     173     print(f'File {year} was already in local storage')
#     175 # load the file into Pandas
# --> 176 rides_one_year = pd.read_parquet(local_file)
#     178 # rename columns
#     179 rides_one_year = rides_one_year[[
#     180     'fecha_origen_recorrido', 'id_estacion_origen']]
#
# File d:\ML System 02\bike_sharing_ML_System\.venv\lib\site-packages\pandas\io\parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     **kwargs,
#     679 )
#
# File d:\ML System 02\bike_sharing_ML_System\.venv\lib\site-packages\pandas\io\parquet.py:265, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     262 if manager == "array":
#     263     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 265 path_or_handle, handles, filesystem = _get_path_or_handle(
#     266     path,
#     267     filesystem,
#     268     storage_options=storage_options,
#     269     mode="rb",
#     270 )
#     271 try:
#     272     pa_table = self.api.parquet.read_table(
#     273         path_or_handle,
#     274         columns=columns,
#    (...)
#     277         **kwargs,
#     278     )
#
# File d:\ML System 02\bike_sharing_ML_System\.venv\lib\site-packages\pandas\io\parquet.py:139, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     129 handles = None
#     130 if (
#     131     not fs
#     132     and not is_dir
#    (...)
#     137     # fsspec resources can also point to directories
#     138     # this branch is used for example when reading from non-fsspec URLs
# --> 139     handles = get_handle(
#     140         path_or_handle, mode, is_text=False, storage_options=storage_options
#     141     )
#     142     fs = None
#     143     path_or_handle = handles.handle
#
# File d:\ML System 02\bike_sharing_ML_System\.venv\lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\ML System 02\\bike_sharing_ML_System\\data\\raw\\rides_2023.parquet'

# %%
from src.data import transform_raw_data_into_ts_data
ts_data = transform_raw_data_into_ts_data(rides)
ts_data
# Out:
# 100%|██████████| 331/331 [00:11<00:00, 28.12it/s]
#                 pickup_hour  rides  pickup_location_id
# 0       2022-01-01 00:00:00      1                   9
# 1       2022-01-01 01:00:00      1                   9
# 2       2022-01-01 02:00:00      1                   9
# 3       2022-01-01 03:00:00      0                   9
# 4       2022-01-01 04:00:00      1                   9
# ...                     ...    ...                 ...
# 2899555 2022-12-31 19:00:00      0                  57
# 2899556 2022-12-31 20:00:00      0                  57
# 2899557 2022-12-31 21:00:00      0                  57
# 2899558 2022-12-31 22:00:00      0                  57
# 2899559 2022-12-31 23:00:00      0                  57
#
# [2899560 rows x 3 columns]

# %%
from src.data import transform_ts_data_into_features_and_target
features, targets = transform_ts_data_into_features_and_target(
    ts_data,
    input_seq_len=28*24*1,
    step_size=24,
    output_seq_len=36
    )
print(f'{features.shape=}')
print(f'{targets.shape=}')
# Out:
# 100%|██████████| 331/331 [01:14<00:00,  4.44it/s]
# features.shape=(111216, 674)
# targets.shape=(111216, 36)

# %%
targets.head(10)
# Out:
#    rides_next_1_hour  rides_next_2_hour  ...  rides_next_35_hour  rides_next_36_hour
# 0                2.0                2.0  ...                 0.0                10.0
# 1                2.0                2.0  ...                 2.0                 2.0
# 2                0.0                0.0  ...                 1.0                 8.0
# 3                0.0                1.0  ...                 2.0                 3.0
# 4                2.0                0.0  ...                 1.0                 4.0
# 5                3.0                1.0  ...                 3.0                 1.0
# 6                4.0                2.0  ...                 0.0                 1.0
# 7                0.0                3.0  ...                 1.0                 1.0
# 8                0.0                0.0  ...                 3.0                 5.0
# 9                0.0                0.0  ...                 3.0                 6.0
#
# [10 rows x 36 columns]

# %%
import pandas as pd
tabular_data = pd.concat([features, targets], axis=1)

from src.paths import  TRANSFORMED_DATA_DIR
tabular_data.to_parquet(TRANSFORMED_DATA_DIR / 'tabular_data.parquet')

# %%
tabular_data.head()
# Out:
#    rides_previous_672_hour  ...  rides_next_36_hour
# 0                      1.0  ...                10.0
# 1                      1.0  ...                 2.0
# 2                      0.0  ...                 8.0
# 3                      4.0  ...                 3.0
# 4                      0.0  ...                 4.0
#
# [5 rows x 710 columns]
